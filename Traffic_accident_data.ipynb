# %% [markdown]
# # Task-05
#
# <i>Analyze traffic accident data to identify patterns related to road conditions, weather, and time of day. Visualize accident hotspots and contributing factors.</i>

# %% [markdown]
# Dataset used can be found here -> [Kaggle](https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents) And for more information on the dataset visit [Here](https://smoosavi.org/datasets/us_accidents)

# %% [markdown]
# ##  Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading the dataset

# %%
df = pd.read_csv("US_Accidents_March23.csv")

# %%
df.head(5)
# Out:
#     ID   Source  Severity           Start_Time             End_Time
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00  \
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False  \
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset
# ...

# %% [markdown]
# ## Information about the dataframe

# %%
df.shape
# Out:
# (7728394, 46)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                        count       mean        std         min         25%
# Severity           7728394.0   2.212384   0.487531    1.000000    2.000000  \
# Start_Lat          7728394.0  36.201195   5.076079   24.554800   33.399631
# Start_Lng          7728394.0 -94.702545  17.391756 -124.623833 -117.219396
# End_Lat            4325632.0  36.261829   5.272905   24.566013   33.462070
# End_Lng            4325632.0 -95.725570  18.107928 -124.545748 -117.754345
# Distance(mi)       7728394.0   0.561842   1.776811    0.000000    0.000000
# Temperature(F)     7564541.0  61.663286  19.013653  -89.000000   49.000000
# Wind_Chill(F)      5729375.0  58.251048  22.389832  -89.000000   43.000000
# Humidity(%)        7554250.0  64.831041  22.820968    1.000000   48.000000
# Pressure(in)       7587715.0  29.538986   1.006190    0.000000   29.370000
# Visibility(mi)     7551296.0   9.090376   2.688316    0.000000   10.000000
# ...

# %%
df.describe(include=object)
# Out:
#              ID   Source           Start_Time             End_Time
# count   7728394  7728394              7728394              7728394  \
# unique  7728394        3              6131796              6705355
# top         A-1  Source1  2021-01-26 16:16:13  2021-11-22 08:00:00
# freq          1  4325632                  225                  112
#
#                                               Description   Street     City
# count                                             7728389  7717525  7728141  \
# unique                                            3761578   336306    13678
# top     A crash has occurred causing no to minimum del...   I-95 N    Miami
# freq                                                 9593    78430   186917
#
#              County    State  Zipcode  Country    Timezone Airport_Code
# count       7728394  7728394  7726479  7728394     7720586      7705759  \
# unique         1871       49   825094        1           4         2045
# ...

# %% [markdown]
# ## Checking for null/missing values in the dataset

# %%
df.isna().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# ...

# %% [markdown]
# ## Dropping the columns with huge number of null values

# %%
df.drop(columns=['End_Lat','End_Lng','Wind_Chill(F)','Precipitation(in)'],axis=1,inplace=True)

# %%
#storing categorical column names to a new variable
categorical=[i for i in df.columns if df[i].dtype=='O']
#for categorical values we can replace the null values with the Mode of it
for i in categorical:
    df[i].fillna(df[i].mode()[0],inplace=True)

# %%
df.drop(columns=['Wind_Speed(mph)', 'Visibility(mi)', 'Pressure(in)', 'Humidity(%)', 'Temperature(F)'], axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# ID                       0
# Source                   0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# Distance(mi)             0
# Description              0
# Street                   0
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Airport_Code             0
# Weather_Timestamp        0
# Wind_Direction           0
# Weather_Condition        0
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# No_Exit                  0
# Railway                  0
# Roundabout               0
# Station                  0
# Stop                     0
# Traffic_Calming          0
# Traffic_Signal           0
# Turning_Loop             0
# Sunrise_Sunset           0
# ...

# %% [markdown]
# ## Checking for duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # EDA

# %% [markdown]
# ## Accident Severity Distribution

# %%
# Count the number of occurrences of each severity level
severity_counts = df['Severity'].value_counts().sort_index()

# Create labels and sizes for the pie chart
labels = ["Least impact", "Moderate impact", "High impact","Significant impact"]
sizes = severity_counts.values
colors = ['#66b3ff', '#99ff99', '#ffcc99', '#ff6666']  # Optional: custom colors

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=60, colors=colors)
plt.title('Accident Severity Distribution')
plt.axis('equal')  # Equal aspect ratio ensures the pie is drawn as a circle.
plt.show()

# %% [markdown]
# ## City with most Number of accidents

# %%
city_acc = df['City'].value_counts().sort_values(ascending = False).reset_index()

# %%
city_acc
# Out:
#                                City   count
# 0                             Miami  187170
# 1                           Houston  169609
# 2                       Los Angeles  156491
# 3                         Charlotte  138652
# 4                            Dallas  130939
# ...                             ...     ...
# 13673                    Bon Secour       1
# 13674                 Sidney Center       1
# 13675                        Fluker       1
# 13676                    Mapleville       1
# 13677  American Fork-Pleasant Grove       1
#
# [13678 rows x 2 columns]

# %% [markdown]
# ## Top 10 cities with most number of accidents

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='City',y='count',data= city_acc.head(10),palette='rocket')
plt.title("Top 10 cities with most number of accidents")
plt.ylabel("No of accidents")
plt.show()
# Out:
# /var/folders/b6/ggrmd6v14nb7yfnbf6dzngf80000gn/T/ipykernel_89609/597650334.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='City',y='count',data= city_acc.head(10),palette='rocket')

# %% [markdown]
# ## Bottom 10 cities with least number of accidents

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='City',y='count',data= city_acc.tail(10),palette='rocket')
plt.title("Bottom 10 cities with least number of accidents")
plt.ylabel("No of accidents")
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/b6/ggrmd6v14nb7yfnbf6dzngf80000gn/T/ipykernel_89609/3520306422.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='City',y='count',data= city_acc.tail(10),palette='rocket')

# %% [markdown]
# ## State with most and least Number of accidents

# %%
state_acc = df['State'].value_counts().sort_values(ascending = False).reset_index()
state_acc
# Out:
#    State    count
# 0     CA  1741433
# 1     FL   880192
# 2     TX   582837
# 3     SC   382557
# 4     NY   347960
# 5     NC   338199
# 6     VA   303301
# 7     PA   296620
# 8     MN   192084
# 9     OR   179660
# 10    AZ   170609
# 11    GA   169234
# 12    IL   168958
# 13    TN   167388
# 14    MI   162191
# 15    LA   149701
# 16    NJ   140719
# 17    MD   140417
# 18    OH   118115
# 19    WA   108221
# 20    AL   101044
# 21    UT    97079
# 22    CO    90885
# 23    OK    83647
# 24    MO    77323
# 25    CT    71005
# 26    IN    67224
# 27    MA    61996
# 28    WI    34688
# 29    KY    32254
# 30    NE    28870
# 31    MT    28496
# 32    IA    26307
# 33    AR    22780
# 34    NV    21665
# 35    KS    20992
# 36    DC    18630
# 37    RI    16971
# 38    MS    15181
# 39    DE    14097
# 40    WV    13793
# 41    ID    11376
# 42    NM    10325
# 43    NH    10213
# 44    WY     3757
# 45    ND     3487
# 46    ME     2698
# 47    VT      926
# 48    SD      289

# %%
## States with most number of accidents
plt.figure(figsize=(15,6))
sns.barplot(x='State',y='count',data= state_acc.head(5),palette='rocket')
plt.title("Top 5 States with most number of accidents")
plt.ylabel("No of accidents")
plt.show()

## States with the least number of accidents
plt.figure(figsize=(15,6))
sns.barplot(x='State',y='count',data= state_acc.tail(5),palette='rocket')
plt.title("Bottom 5 States with least number of accidents")
plt.ylabel("No of accidents")
plt.show()
# Out:
# /var/folders/b6/ggrmd6v14nb7yfnbf6dzngf80000gn/T/ipykernel_89609/3569853493.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='State',y='count',data= state_acc.head(5),palette='rocket')
# /var/folders/b6/ggrmd6v14nb7yfnbf6dzngf80000gn/T/ipykernel_89609/3569853493.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='State',y='count',data= state_acc.tail(5),palette='rocket')

# %% [markdown]
# `Observations:`
# - Miami is the city with most number of accidents
# - starjunction, stomsburg are among the cities with least number of accidents
# - California is the state with highest cases of accident
# - South Dakota(SD) is the state with least cases of accident

# %%
df['Severity'].value_counts().index
# Out:
# Index([2, 3, 4, 1], dtype='int64', name='Severity')

# %%
plt.figure(figsize=(8,8))
plt.pie(df['Severity'].value_counts(),labels=['severe','more-severe','most-severe','least-severe'],autopct="%1.2f%%")
plt.show()

# %%
# Convert the 'Start_Time' column to datetime format
df['Start_Time'] = pd.to_datetime(df['Start_Time'], errors='coerce')

# Extract the year from the 'Start_Time' column and store it in a new column called 'Year'
df['Year'] = df['Start_Time'].dt.year

# Display the first few rows to verify
print(df[['Start_Time', 'Year']].head())
# Out:
#            Start_Time    Year
# 0 2016-02-08 05:46:00  2016.0
# 1 2016-02-08 06:07:59  2016.0
# 2 2016-02-08 06:49:27  2016.0
# 3 2016-02-08 07:23:34  2016.0
# 4 2016-02-08 07:39:07  2016.0

# %%
df['Year'].value_counts()
# Out:
# Year
# 2021.0    1412433
# 2022.0    1268806
# 2020.0    1161598
# 2019.0     954302
# 2018.0     893426
# 2017.0     717290
# 2016.0     410821
# 2023.0     166552
# Name: count, dtype: int64

# %% [markdown]
# ## Years with most number of accidents

# %%
year_count = df['Year'].value_counts().reset_index()
sns.barplot(x='Year',y='count',data=year_count,palette='rocket')
plt.title("Years with most number of accidents")
plt.show()
# Out:
# /var/folders/b6/ggrmd6v14nb7yfnbf6dzngf80000gn/T/ipykernel_89609/2601685927.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year',y='count',data=year_count,palette='rocket')

# %% [markdown]
# `Observation:`
# - year 2021 had highest accident rates.

# %% [markdown]
# ## Weather conditions at the time of accidents

# %%
weather = df['Weather_Condition'].value_counts().sort_values(ascending=False).reset_index()
sns.barplot(x='count',y='Weather_Condition',data=weather[:10],orient='horizontal',palette='rocket')
plt.show()
# Out:
# /var/folders/b6/ggrmd6v14nb7yfnbf6dzngf80000gn/T/ipykernel_89609/264243845.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='count',y='Weather_Condition',data=weather[:10],orient='horizontal',palette='rocket')

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df['Start_Lng'],y=df['Start_Lat'],hue=df['State'],palette="Reds")
plt.legend(loc="lower right")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df['Start_Lng'],y=df['Start_Lat'],hue=df['Severity'])
plt.show()
# Out:
# /Users/alimuddinkhan/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Conclusion:
#
# This traffic data analysis project involved a detailed review of accident records, including data cleaning, exploratory data analysis (EDA), and visualization. The main findings from the analysis are outlined below:
#
# 1. **City-wise Accident Distribution**:
#    - **Miami** had the highest number of accidents, likely due to its large population and high traffic density.
#    - Smaller cities like **Star Junction** and **Stromsburg** reported the fewest accidents, reflecting their lower traffic and population levels.
#
# 2. **State-wise Accident Distribution**:
#    - **California** recorded the most accidents, consistent with its large population and extensive road network.
#    - **South Dakota (SD)** had the fewest accidents, likely due to its lower population density and reduced traffic volume.
#
# 3. **Yearly Accident Trends**:
#    - The year **2021** saw the highest number of accidents, suggesting either an increase in traffic or changes in accident reporting during that period.
#
# 4. **Accident Severity**:
#    - Accidents were categorized into four severity levels: 1, 2, 3, and 4.
#    - Most accidents were classified as **severity level 2**, indicating that while accidents were common, they were generally not highly severe.
#
# 5. **Weather Conditions During Accidents**:
#    - A majority of accidents occurred in **fair weather**, indicating that other factors like driver behavior or traffic congestion were likely more influential in causing accidents than poor weather conditions.
#
# These findings offer valuable insights into accident patterns and locations, providing crucial information for shaping policy, enhancing urban planning, and implementing safety measures to reduce both the occurrence and impact of traffic accidents.
